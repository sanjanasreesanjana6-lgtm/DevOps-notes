# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanasreesanjana6-lgtm/DevOps-notes/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sum_mul(n, m):
    sum=0
    if n> 0 and m> 0:
       for i in range (n, m):
            if (i % n == 0):
                sum +=i
    else:
        return("INVALID")
    return sum
print(sum_mul(2,6))
# Out:
# 6
